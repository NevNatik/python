# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Наталья, привет!👋</b>
#
# Меня зовут Арина У., я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет.
#
# Цель проекта : научиться определять рыночную стоимость объектов недвижимости с разными параметрами в обьявлениях
#
#
# ## Описание данных
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах(м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении
#
# Ход работы следующий:
#
# - <a href='#Шаг 2. Предобработка данных'>
#     Провести предобработку данных. Отработать пропущенные значений, продумать правильное решение по заполнению пропусков.</a>
# - <a href='#Шаг 4. Проведите исследовательский анализ данных и выполните инструкции'>
#     Проведите исследовательский анализ данных. Построить гистограммы по главным критериям продаж квартир </a>
#
# - <a href='#Шаг 5. Общий вывод'> Описать свои выводы исследования </a>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здорово, что ты начинаешь проект с краткого введения, это правильный шаг на пути к правильному оформлению работы: я бы порекомендовала тебе оформлять введение с помощью гиперссылок в ячейках Markdown, с их помощью можно добавить и оформить введение с основными шагами. Информация о том, как это сделать, ты можешь найти по ссылке:
#
# https://sebastianraschka.com/Articles/2014_ipython_internal_links.html
#
# https://coderoad.ru/11948245/Markdown-для-создания-страниц-и-оглавления
#
# https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd
#
# P.S. Также я бы рекомендовала фиксировать основную цель проекта, это тоже очень важно!👀

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что ты добавила контент-план, все получилось!

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl


real_estate_data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t', decimal=',')

display(real_estate_data.head(10))
#Общая информация о таблице
real_estate_data.info()
# Out:
#    total_images  last_price total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.0  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.4  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.3  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.6  2019-04-18T00:00:00      2
# 8            20   2900000.0      33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.0  2017-02-26T00:00:00      3
#
#   ceiling_height floors_total living_area  floor is_apartment  ...  \
# 0            2.7         16.0        51.0      8          NaN  ...
# 1            NaN         11.0        18.6      1          NaN  ...
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Просмотр данных, общая информация по столбцам показало:
# 1. Таблица из 23699 строк
# 2.  В таблице есть столбцы с пропущенными данными: ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition. Надо провести анализ как можно заполнить пропущенные данные или оставить как есть
# 3.  Несоответствие типов. Необходимо провести замену типа данных по следующим столбцам:
#
#
#
# - balcony перевести в int
# - ceiling_height перевести в float
# - cityCenters_nearest перевести в float
# - days_exposition перевести в int
# - first_day_exposition перевести в date
# - floors_total перевести в int
# - kitchen_area перевести в float
# - last_price перевести в float
# - living_area перевести в float
# - total_area перевести в int
#
# Нужно провести преобработку данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, ты наметила основной план работы, разобралась названиями колонок, отметила наличие пропусков, аномальных значений, давай посмотрим, что у тебя получилось на следующих шагах анализа!

# %% [markdown]
# ### Шаг 2. Предобработка данных
# <a id='Шаг 2. Предобработка данных'></a>

# %%
print('Кол-во пропусков')
#report = real_estate_data.isnull().sum()*100/len(real_estate_data)
report = real_estate_data.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / real_estate_data.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)

print(report)
# Out:
# Кол-во пропусков
#                       missing_values  % of total
# total_images                       0        0.00
# last_price                         0        0.00
# total_area                         0        0.00
# first_day_exposition               0        0.00
# rooms                              0        0.00
# ceiling_height                  9195        0.39
# floors_total                      86        0.00
# living_area                     1903        0.08
# floor                              0        0.00
# is_apartment                   20924        0.88
# studio                             0        0.00
# open_plan                          0        0.00
# kitchen_area                    2278        0.10
# balcony                        11519        0.49
# locality_name                     49        0.00
# airports_nearest                5542        0.23
# cityCenters_nearest             5519        0.23
# parks_around3000                5518        0.23
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Иногда бывает полезно посмотреть не просто на пропуски в данных, а на процент пропусков по колонкам, это можно сделать,  например, так:
#
# `data.isnull().sum()*100/len(data)`
#
# Более продвинутый вариант (кол-во пропусков + процент пропусков)
#
# `report = data.isna().sum().to_frame()
# report = report.rename(columns = {0: 'missing_values'})
# report['% of total'] = (report['missing_values'] / data.shape[0]).round(2)
# report.sort_values(by = 'missing_values', ascending = False)`
#
# Это полезное действие при подборе стратегии заполнения пропусков: обычно, если в данных кол-во пропусков превышает 10%, восполнение пропусков результатами выполнения стандартных операций типа расчета среднего/медианы по столбцу, может привести к искажению данных. Если мы сталкиваемся с такой ситуацией, то важно подумать и подобрать более сложную восполнения пропусков в данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что ты попробовала реализовать этот код, выглядит отлично!

# %% [markdown]
# ### Вывод

# %% [markdown]
# Проведем преобработку столбцов:
#
# - ceiling_height
# - balcony
# - floors_total
# - living_area
# - total_area
# - kitchen_area
# - cityCenters_nearest
# - last_price
# - first_day_exposition
# - days_exposition
#
# т.к они нам понадобятся для дальнейшего анализа
#
# Все остальные пропущенные данные в столбцах оставим без изменения, т.к. они никакой в иссследовании о продаже квартир не играют важно роли.

# %%
# Работа с пропущенными данными в столбце ceiling_height (высота потолков (м))

#переведем значения столбца в вещественный тип
real_estate_data['ceiling_height']= pd.to_numeric(real_estate_data['ceiling_height'])

print('Кол-во пропущенных значений в ceiling_height', real_estate_data['ceiling_height'].isnull().sum())

#провела группировку по населенному пункту, всего этаже в доме и высота потолков
for i, r in real_estate_data.groupby(['locality_name','floors_total','ceiling_height']):
    for row_index, row in r.iterrows():
        ln = row['locality_name']
        ft = row['floors_total']
        # Ищу пустые значения в столбце ceiling_height, по населенному пункту и кол-во этажей
        for i2,r2 in real_estate_data.query('ceiling_height.isnull() and locality_name == @ln and floors_total == @ft').iterrows():
            #записываю высоту с одинаковым населенным пунктом и кол-во этажей
            real_estate_data.loc[i2, 'ceiling_height'] = row['ceiling_height']
            
#Остальную часть пропусков заполняю средним значением по высоте потолков
med_ceiling_height = real_estate_data['ceiling_height'].median()
print('Среднее арифметическое значение потолков:', med_ceiling_height)

#Полученную значение пропишем в пропусках в столбце 'ceiling_height'
real_estate_data['ceiling_height']= real_estate_data['ceiling_height'].fillna(med_ceiling_height)

print('Кол-во пропущенных значений после обработки в ceiling_height', real_estate_data['ceiling_height'].isnull().sum())
# Out:
# Кол-во пропущенных значений в ceiling_height 9195
# Среднее арифметическое значение потолков: 2.55
# Кол-во пропущенных значений после обработки в ceiling_height 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Пропущенные записи в столбце ceiling_height заполняю следующим образом:
#
# 1. Группирую данные населенные пункты с кол-вами тажей и высота потолков. Это нам необходимо для того чтобы найти похожием дома с одинаковыми признаками.
# 2. Создаем срез где отсутсвует высота потолков, но населенный пункт и этажность совпадает.
# 3. Проставляю в пропущенных записях значения из группировки
# 4. Оставшиеся записи которые не нашлись по группировке я заполнила значением медианы.
#
# Следующий этап обработки это вывод графика размаха и получение нормальных значений.

# %%
#Строю график размаха  для столбца ceiling_height
plt.ylim(real_estate_data['ceiling_height'].min(), real_estate_data['ceiling_height'].max())
bp = plt.boxplot(real_estate_data['ceiling_height'])
plt.show()
# Получаем значения квантилий Q1 и Q3
Q1 = bp['whiskers'][0].get_ydata()[1]
Q3 = bp['whiskers'][1].get_ydata()[1]
print('Q1-', Q1)
print('Q3-', Q3)

# Пересоздаю таблицу с нормальными значнеиями в столбце  ceiling_height входящие в отрезок Q1 и Q3
real_estate_data= real_estate_data.query('(ceiling_height>=@Q1)&(ceiling_height<=@Q3)')

real_estate_data.info()
# Out:
# Q1- 2.2
# Q3- 3.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20551 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            20551 non-null int64
# last_price              20551 non-null object
# total_area              20551 non-null object
# first_day_exposition    20551 non-null object
# rooms                   20551 non-null int64
# ceiling_height          20551 non-null float64
# floors_total            20465 non-null object
# living_area             18904 non-null object
# floor                   20551 non-null int64
# is_apartment            2376 non-null object
# studio                  20551 non-null bool
# open_plan               20551 non-null bool
# kitchen_area            18600 non-null object
# balcony                 10732 non-null object
# locality_name           20506 non-null object
# airports_nearest        15219 non-null object
# cityCenters_nearest     15237 non-null object
# parks_around3000        15238 non-null object
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# <a id='графика размаха'></a> С помощью графика размаха мы определили отрезок с нормальными значениями по столбцу ceiling_height.
#
# - Q1 = 2.2
# - Q3 = 3.0
#
# Пересоздали таблицу real_estate_data с помощью среза данных. В таблице осталось 20551 записей.

# %%
# Работа с пропущенными данными в столбце balcony (число балконов)
print('Кол-во пропущенных значений в balcony', real_estate_data['balcony'].isnull().sum())
# проставим 0 там где не указано кол-во балконов
real_estate_data['balcony'] = real_estate_data['balcony'].fillna('0.0')
print('Кол-во пропущенных значений после обработки в balcony', real_estate_data['balcony'].isnull().sum())

#переведем значения столбец в вещественный тип
real_estate_data['balcony']= pd.to_numeric(real_estate_data['balcony'])
#переведем значения столбец в целочисленный тип
real_estate_data['balcony'] = real_estate_data['balcony'].astype('int')
# Out:
# Кол-во пропущенных значений в balcony 9819
# Кол-во пропущенных значений после обработки в balcony 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обработка столбца balcony:
#
# 1.  Проставить значение 0 там, где пропущенно. Скорее всего оператор не указал кол-во балконов из за их отсутствия
# 2.  Изменить тип данных в int. Сначало строковое значение переводим во float, потом переводим в тип int.

# %%
# Работа с пропущенными данными в столбце floors_total (всего этажей в доме)
print('Кол-во пропущенных значений в floors_total', real_estate_data['floors_total'].isnull().sum())
# проставим 0 там где не указано кол-во этажей в доме
real_estate_data['floors_total'] = real_estate_data['floors_total'].fillna('1.0')
print('Кол-во пропущенных значений после обработки в floors_total', real_estate_data['floors_total'].isnull().sum())

#переведем значения столбца в вещественный тип
real_estate_data['floors_total']= pd.to_numeric(real_estate_data['floors_total'])
#переведем значения столбца в целочисленный тип
real_estate_data['floors_total'] = real_estate_data['floors_total'].astype('int')
# Out:
# Кол-во пропущенных значений в floors_total 86
# Кол-во пропущенных значений после обработки в floors_total 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обработка столбца floors_total:
#
# 1.  Проставить значение 1 там, где пропущенно. Скорее всего оператор не указал кол-во этажей, т.к квартирный дом с одним этажом.
# 2.  Изменить тип данных в int. Сначало строковое значение переводим во float, потом переводим в тип int.

# %%
#переведем значения столбцов total_area, living_area, kitchen_area, cityCenters_nearest в вещественный тип
real_estate_data['total_area']= pd.to_numeric(real_estate_data['total_area'])
real_estate_data['living_area']= pd.to_numeric(real_estate_data['living_area'])
real_estate_data['kitchen_area']= pd.to_numeric(real_estate_data['kitchen_area'])
real_estate_data['cityCenters_nearest']= pd.to_numeric(real_estate_data['cityCenters_nearest'])

# Работа с пропущенными данными в столбце living_area (жилая площадь в квадратных метрах(м²))
# Находим кооэффициент среднее отношение жилой площади к общей по всей таблице
k = real_estate_data['living_area'].mean()/real_estate_data['total_area'].mean()
print('Кооэффициент жилой площади ',k)
print('Кол-во пропущенных значений в living_area', real_estate_data['living_area'].isnull().sum())
# Там где пропущенные данные делаем расчет жилой площади = коэффициент * на общую площадь квартиры
real_estate_data['living_area'] = real_estate_data['living_area'].fillna(k*real_estate_data['total_area'])
print('')

# Работа с пропущенными данными в столбце kitchen_area (площадь кухни в квадратных метрах (м²))
# Находим среднее отношение площади кухни к общей по всей таблице
k_kitchen = real_estate_data['kitchen_area'].mean()/real_estate_data['total_area'].mean()
print('Кооэффициент площади кухни ',k_kitchen)
print('Кол-во пропущенных значений в kitchen_area', real_estate_data['kitchen_area'].isnull().sum())
# Там где пропущенные данные делаем расчет площади кухни = коэффициент * на общюю площадь квартиры
real_estate_data['kitchen_area'] = real_estate_data['kitchen_area'].fillna(k_kitchen*real_estate_data['total_area'])
print('')

# Работа с пропущенными данными в столбце lcityCenters_nearest (расстояние до центра города (м))
print('Кол-во пропущенных значений в cityCenters_nearest', real_estate_data['cityCenters_nearest'].isnull().sum())
# Там где пропущенные данные делаем замену на среднее расстояние до центра города
real_estate_data['cityCenters_nearest'] = real_estate_data['cityCenters_nearest'].fillna(real_estate_data['cityCenters_nearest'].mean())
print('')

print('Кол-во пропущенных значений после обработки в living_area', real_estate_data['living_area'].isnull().sum())
print('Кол-во пропущенных значений после обработки в kitchen_area', real_estate_data['kitchen_area'].isnull().sum())
print('Кол-во пропущенных значений после обработки в cityCenters_nearest', real_estate_data['cityCenters_nearest'].isnull().sum())
# Out:
# Кооэффициент жилой площади  0.5635942041235206
# Кол-во пропущенных значений в living_area 1647
#
# Кооэффициент площади кухни  0.17949401707873316
# Кол-во пропущенных значений в kitchen_area 1951
#
# Кол-во пропущенных значений в cityCenters_nearest 5314
#
# Кол-во пропущенных значений после обработки в living_area 0
# Кол-во пропущенных значений после обработки в kitchen_area 0
# Кол-во пропущенных значений после обработки в cityCenters_nearest 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обработка столбца living_area:
#
# 1. Изменить тип данных object на тип  float столбцов total_area и living_area.
# 2. Находим среднее отношение жилой площади к общей по всей таблице
# результат равен  0.5635
# 3. Там где пропущенные данные делаем расчет жилой площади по формуле коэффициент * на общую площадь квартиры
#
#
# Обработка столбца kitchen_area:
#
# 1. Изменить тип данных object на тип  float столбец kitchen_area.
# 2. Находим среднее отношение площади кухни к общей по всей таблице
# результат равен 0.1794
# 3. Там где пропущенные данные делаем расчет площади кухни по формуле коэффициент * на общую площадь квартиры
#
# Обработка столбца cityCenters_nearest:
#
# 1. Изменить тип данных object на тип  float
# 2. Там где пропущенные данные делаем замену на среднее расстояние до центра города

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Наталья, ты предложила стратегию заполнения пропусков в колонке `ceiling_height`и других колонках, но важно понимать риски тех способов, которые ты используешь для обработки пропусков.
#
# Например, не совсем корректно заменять пропуски в ceiling_height на среднее или медианное значение потолков (насколько я поняла, ты производишь замену на медиану по столбцу). В этой колонке отсутствует около 38% данных. Это очень много, и сложно найти веские причины для таких радикальных трансформаций. А в случае замены на конкретное значение без ссылки на источники - это, скорее, искажение исходных данных, а не их обогащение.
#
# Такая стратегия удачна для переменных, в которых отсутствует до 10% данных.
#
# Зачем мы вообще проводим EDA? Есть два пункта:
# 1. Мы хотим получить какие-то инсайты о данных (средние значения, минимумы, максимумы и т.д.), чтобы описать, например, среднестатистическую продаваемую квартиру.
# 2. Мы хотим проверить, подходят ли данные для моделирования (смотрим на аномалии, распределения переменных и другие характеристики) — об этом ты узнаешь в последующих уроках🙌
#
# Соответственно, мы должны быть очень осторожны с изменением изначальных данных. Трансформации с булевыми переменными не должны сильно повлиять на наши будущие интерпретации, так как логика замены ооочень сильная: если нет полижительного ответа, значит, он отрицательный. Но все остальные преобразования — под вопросом, поскольку это искусственная замена.
#
#
# Конечно, последнее слово всегда за экспертом, аналитиком, но в реальной жизни важно понимать вероятность того, что объективность данных может быть искажена подобными. Чтобы доказать обратное, можно, например, сравнить распределения и ключевые статистики до и после замены.
#
# Хочу посоветовать тебе статью, которая рассматривает разные способы обработки пропусков, выделяет их плюсы и минусы, думаю, тебе может быть интересно: https://loginom.ru/blog/missing
#
# Какие стратегии замены были бы наименее "болезненными" и  "искажающими"? Можно попробовать заполнить пропуски по группировкам. Или построить корреляционную матрицу, посмотреть, какие переменные коррелируют между собой, и на основе корреляции и группировки заполнить пропуски.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b>
#
# Я заметила, что ты обработала значение в 100 м в высоте потолков, заменив их на 10. В целом действия по удалению аномальных значений важно реализовать на этапе работы с выбросами. Помимо 100 м в этой и других колонках могут быть другие выбросы, и в целом, лучше определить выбросы с помощью специальных методов (IQR, z-статистика, графический метод (боксплоты).

# %%
#Переведем значения столбцов в вещественный тип
real_estate_data['last_price']= pd.to_numeric(real_estate_data['last_price'])
real_estate_data['days_exposition']= pd.to_numeric(real_estate_data['days_exposition'])

#Переведем значения столбца в тип datetime
real_estate_data['first_day_exposition'] = pd.to_datetime(real_estate_data['first_day_exposition'])

#Итог обработки типов данных
print(real_estate_data.dtypes)
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                    object
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest                object
# cityCenters_nearest            float64
# parks_around3000                object
# parks_nearest                   object
# ponds_around3000                object
# ponds_nearest                   object
# days_exposition                float64
# dtype: object

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для дальнейших расчетов изменила тип данных столбцам:
#
# - last_price из строкового типа в float
# - first_day_exposition из строкового типа в datetime
# - days_exposition из строкового в float

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b>
#
# Типы данных заменены корректно!

# %% [markdown]
# ### Шаг 3. Посчитайте и добавьте в таблицу

# %%
#Цена квадратного метра с округлением
real_estate_data['price_kv'] = round(real_estate_data['last_price']/real_estate_data['total_area'])

display(real_estate_data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 3             0  64900000.0       159.0           2015-07-24      3
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8          NaN  ...
# 1            2.55            11    18.600000      1          NaN  ...
# 3            2.47            14    89.611478      9          NaN  ...
# 5            2.50            12    14.400000      5          NaN  ...
# 6            2.50            26    10.600000      6          NaN  ...
#
#    balcony              locality_name  airports_nearest  cityCenters_nearest  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Провела расчет стоимости квадратного метра и добавила расчет в столбец price_kv
#
# Стоимости 1кв.м = округление(Цена/Площадь квартиры (кв.м))

# %%
#Добавим столбец "День недели"

#Функция перевода цифры дня недели в наименование
def weeekday(day):
    d = {0: 'Понедельник', 1:'Вторник', 2:'Среда',3:'Четерг',4:'Пятница',5:'Суббота', 6:'Воскресенье'}
    for key in d:
        if day == key:
             return d[key]
#переход по строкам и запись в столбец            
for index,row in real_estate_data.iterrows():
    real_estate_data.loc[index, 'day_week'] = weeekday(row['first_day_exposition'].weekday()) 
display(real_estate_data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 3             0  64900000.0       159.0           2015-07-24      3
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8          NaN  ...
# 1            2.55            11    18.600000      1          NaN  ...
# 3            2.47            14    89.611478      9          NaN  ...
# 5            2.50            12    14.400000      5          NaN  ...
# 6            2.50            26    10.600000      6          NaN  ...
#
#                locality_name  airports_nearest  cityCenters_nearest  \
# ...

# %%
#Добавим столбцы "месяц", "год"

#Функция перевода цифры месяца в наименование
def month_naim(mth):
    d = {1: 'Январь', 2:'Февраль', 3:'Март', 4:'Апрель', 5:'Май', 6:'Июнь', 7:'Июль', 8:'Август', 9:'Сентябрь', 10:'Октябрь', 11:'Ноябрь', 12:'Декабрь'}
    for key in d:
        if mth == key:
             return d[key]
            
#Проходим по строкам и записываем в столбцы month, year 
for i, r in real_estate_data.iterrows():
    real_estate_data.loc[i, 'month'] =  month_naim(r['first_day_exposition'].month)
    real_estate_data.loc[i, 'year'] =  r['first_day_exposition'].year
    
# переводим значения столбца year  в тип int   
real_estate_data['year'] =  real_estate_data['year'].astype('int')



display(real_estate_data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 3             0  64900000.0       159.0           2015-07-24      3
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8          NaN  ...
# 1            2.55            11    18.600000      1          NaN  ...
# 3            2.47            14    89.611478      9          NaN  ...
# 5            2.50            12    14.400000      5          NaN  ...
# 6            2.50            26    10.600000      6          NaN  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Создала три столбца связанный с датой first_day_exposition (дата публикации):
# - day_week- день недели.
# - month- месяц
# - year- год
#
# Для работы создала функции со словарями (дни неделя, месяцы)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b>
#
# На этом этапе все действия и расчеты верны!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Кажется, библиотека pandas позволяет решить задачу по выделению названий дней недели и месяцев намного более короче: например, есть такой метод как `day_name()` и `month_day()`, которые автоматически добавляют названия дней и месяцев
#
#
# https://www.geeksforgeeks.org/python-pandas-series-dt-day_name/
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.day_name.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.month_name.html
#
# https://www.geeksforgeeks.org/python-pandas-series-dt-month_name/

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий на ваше замечание</h2>
#
# month_day() попробовала использовать. Он выводит наименование на англ. языке. Для русского языка библиотека  import locale не поддерживает параметр locale='Russian'. Я чуть позже изучу эту тему и попробую в работе.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Да, хорошо, что попробовала! Да, действительно, вывод на английском языке, это просто интересные методы, которые можно изучить для себя и использовать в работе, если будет потребность!

# %%
# Столбец "этаж квартиры"
# варианты — первый, последний, другой;
def floor_naim(fl, fl_total):
    d = {1: 'Первый', 2:'Другой', 3:'Последний'}
    dc = 2
    if fl == 1 and fl != fl_total:
        dc = 1
    if fl > 1 and fl != fl_total:
        dc = 2
    if fl > 1 and fl == fl_total:
        dc = 3
    return [d[dc], dc]
            
# в столбец floor_naim указываю результат условия по полям floor и floors_total
for i,r in real_estate_data.iterrows():
    fl_res = floor_naim(r['floor'], r['floors_total'])
    real_estate_data.loc[i, 'floor_naim'] = fl_res[0]
    real_estate_data.loc[i, 'floor_naim_id'] = fl_res[1]

display(real_estate_data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 3             0  64900000.0       159.0           2015-07-24      3
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8          NaN  ...
# 1            2.55            11    18.600000      1          NaN  ...
# 3            2.47            14    89.611478      9          NaN  ...
# 5            2.50            12    14.400000      5          NaN  ...
# 6            2.50            26    10.600000      6          NaN  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  price_kv  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В целом решение через `.loc()` верное, но можно в данном случае попытаться написать функцию, которая дает тот же результат.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# У тебя получилась отличная функция, молодец!

# %% [markdown]
# ### Вывод

# %% [markdown]
# Создала столбец floor_naim, в котором будет хранится хранится этажность квартиры.
# Заполнение столбца выполнилось по условиям:
#
# 1. Если этаж первый и не равен количеству всего этажей, или кол-во этажей равно 1, значит это первый этаж
# 2. Если этаж не первый и не равен количеству всего этажей, значит это этаж с пометкой "Другой"
# 3. Если этаж не первый и равен количеству всего этажей, то значит это последний этаж

# %%
# Расчёт соотношение жилой и общей площади
# создала новый столбец K, которая заполняется путем вычисления жилая площадь/общую площадь
for ind, row in real_estate_data.iterrows():
    real_estate_data.loc[ind, 'K'] = row['living_area']/row['total_area']
    
# Расчёт отношение площади кухни к общей
# создала новый столбец K_kitchen, которая заполняется путем вычисления площадь кухни/общую площадь
for ind, row in real_estate_data.iterrows():
    real_estate_data.loc[ind, 'K_kitchen'] = row['kitchen_area']/row['total_area']
    
display(real_estate_data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 3             0  64900000.0       159.0           2015-07-24      3
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8          NaN  ...
# 1            2.55            11    18.600000      1          NaN  ...
# 3            2.47            14    89.611478      9          NaN  ...
# 5            2.50            12    14.400000      5          NaN  ...
# 6            2.50            26    10.600000      6          NaN  ...
#
#    ponds_nearest  days_exposition  price_kv     day_week     month  year  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Создала столбцы:
# - K
#
# формула расчета следующаяя, жилую площадь квартиры поделила на общую площадь квартиры.
# - K_kitchen
#
#
# формула расчета следующаяя, площадь кухни поделила на общую площадь квартиры.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# ### Шаг 4. Проведите исследовательский анализ данных и выполните инструкции
# <a id='Шаг 4. Проведите исследовательский анализ данных и выполните инструкции'></a>

# %%
# гистограммы площади квартиры в квадратных метрах (м²)
print(real_estate_data['total_area'].describe())
 
real_estate_data['total_area'].hist(bins=250, range=(real_estate_data['total_area'].min(), real_estate_data['total_area'].max()))
plt.title('Площади квартиры в квадратных метрах (м²)')
plt.xlabel("total_area")
plt.show()
# Out:
# count    20551.000000
# mean        57.159185
# std         29.631622
# min         12.000000
# 25%         39.100000
# 50%         50.400000
# 75%         66.300000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для того чтобы точно сказать с какой позиции начинается и заканчиваются площади квартир. вызвала метод describe.
# Стало известно что гистограмма начинает свой показатель от 12 м.кв площади квартир. Пиком графика, а значит большим спросом покупки квартиры площадью от 60 м.кв. Меньшим спросом квартиры от 100 м.кв.
# Распределение спроса квартир в нормальной форме графика,у которого симметричная форма колокола с пиком посередине

# %%
# гистограмма цен на квартиры

print(real_estate_data['last_price'].describe()/1000)
real_estate_data.hist(column = 'last_price', bins=50)
plt.title('Цены на квартиры')
plt.xlabel("last_price")
plt.show()
# Out:
# count        20.551000
# mean       5833.011524
# std        9045.573989
# min          12.190000
# 25%        3300.000000
# 50%        4500.000000
# 75%        6300.000000
# max      763000.000000
# Name: last_price, dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Размерность цен на квартиру начинается от 12 тысяч рубллей, пиком ценового показателя в области 6 миллионов рублей.
# Большой пикой на графике показан почти 75% сумма квартир от 6.8 млн. рублей

# %%
# гистограмма число комнат в квартирах
print(real_estate_data['rooms'].describe())

real_estate_data['rooms'].hist(bins= 50)
plt.title('Число комнат в квартирах')
plt.xlabel("rooms")
plt.show()
# Out:
# count    20551.000000
# mean         1.981461
# std          0.988349
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         16.000000
# Name: rooms, dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# График показывает рынок квартир с кол-вами комнат.  Из 20 551 предложенных вариантов, предпочтение составляет 50% 2-х комнатные квартиры, 75 %  3-х комнатные апартаменты.

# %%
# гистограмма высота потолков в квартирах
print(real_estate_data['ceiling_height'].describe())
real_estate_data['ceiling_height'].hist(bins= 30)
plt.title('Высота потолков в квартирах')
plt.xlabel("ceiling_height")
plt.show()
# Out:
# count    20551.000000
# mean         2.593691
# std          0.156137
# min          2.200000
# 25%          2.500000
# 50%          2.550000
# 75%          2.700000
# max          3.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Наталья, ты выбрала корректные типы графиков для изучения характеристик высоты потолков, но  стоит уделять больше внимания оформлению графиков, если ты используешь их в работе: важно добавлять названия осей и заголовки на русском языке и убирать технические строчки с помощью метода `plt.show()`

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Теперь графики оформлены более корректно! Заголовки добавили информативности!

# %% [markdown]
# ### Вывод

# %% [markdown]
# График показывает варианты квартир с высотой потолков.  В обьявлениях средний размер высота потолков составляет 2,5 м.
#
# 75% обьявлений преддогают потолки с высотой 2,7м. Максимальная высота потолков 3 м.
#
# Еще надо помнить что в части где была <a href='#графика размаха'> обработка данных </a> я провела выброс дынных с помощью метода Боксплота

# %%
# гистограмма по времени продажи квартиры
real_estate_data['days_exposition'].hist(bins= 80)
print('Среднее кол-во дней публикации обьявления {} дней'.format(real_estate_data['days_exposition'].median()))
print('Среднее арифметическое кол-во дней публикации обьявления {:.1f} дней'.format(real_estate_data['days_exposition'].mean()))
plt.title('По времени продажи квартиры')
plt.xlabel("days_exposition")
plt.show()
# Out:
# Среднее кол-во дней публикации обьявления 93.0 дней
# Среднее арифметическое кол-во дней публикации обьявления 176.4 дней

# %% [markdown]
# ### Вывод

# %% [markdown]
# График показывает кол-во дней публикации обьявления продажи квартиры.
#
# В среднем обьявление имеет статус публикации 95 дней,
# среднее арифметическое кол-во дней публикации обьявления равна 176 дней.
#
#
# Можно считать, что продажи прошли очень быстро, если количество дней публикации объвления значительно меньше медианы и соответственно долго когда количество дней публикации больше среднее арифметического.

# %%
'''
# Собираем количественный посчет по цене 
counts = real_estate_data['last_price'].value_counts()

# Исключает с таблицы редковстречающие цены те, которые в таблице 1 раз.
real_estate_data = real_estate_data.loc[real_estate_data['last_price'].isin(counts[counts > 1].index), :]
real_estate_data.info()
'''

#Строю график размаха  для столбца ceiling_height
plt.ylim(real_estate_data['last_price'].min(), real_estate_data['last_price'].max())
last_pr = plt.boxplot(real_estate_data['last_price'])
plt.show()
# Получаем значения квантилий Q1 и Q3
Q1 = last_pr['whiskers'][0].get_ydata()[1]
Q3 = last_pr['whiskers'][1].get_ydata()[1]
print('Q1-', Q1)
print('Q3-', Q3)

# Пересоздаю таблицу с нормальными значнеиями в столбце  ceiling_height входящие в отрезок Q1 и Q3
real_estate_data= real_estate_data.query('(last_price>=@Q1)&(last_price<=@Q3)')

real_estate_data.info()
# Out:
# Q1- 12190.0
# Q3- 10800000.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18950 entries, 1 to 23698
# Data columns (total 30 columns):
# total_images            18950 non-null int64
# last_price              18950 non-null float64
# total_area              18950 non-null float64
# first_day_exposition    18950 non-null datetime64[ns]
# rooms                   18950 non-null int64
# ceiling_height          18950 non-null float64
# floors_total            18950 non-null int64
# living_area             18950 non-null float64
# floor                   18950 non-null int64
# is_apartment            2176 non-null object
# studio                  18950 non-null bool
# open_plan               18950 non-null bool
# kitchen_area            18950 non-null float64
# balcony                 18950 non-null int64
# locality_name           18912 non-null object
# airports_nearest        13654 non-null object
# cityCenters_nearest     18950 non-null float64
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Методом boxplot получили нормальные значения цен на квартиры. Границы квантилий от 12190 до 10800000 руб.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b>
#
# Наталья, один из пунктов инструкции к проекту сформулирован так:
#
# `Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.`
#
# Поэтому, важно проверить данные на выбросы (все факторы,столбцы, переменные, которые ты исследуешь)
#
# Для изучения и удаления выбросов как минимум стоит использовать графический метод, в частности, график ящик с усами (о других методах я писала выше, материалы по методам идентификации и удаления выбросов прикладываю ниже)
#
# Поэтому этот шаг важно доработать: выбрать метод для работы с выбросами, аргументировать свой выбор, удалить редкие и выбивающиеся значения, сравнить результат с полным датасетом.
#
# Полезная статья по методам работы с выбросами:
#
# https://www.machinelearningmastery.ru/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623/
#
# https://proglib.io/p/moem-dataset-rukovodstvo-po-ochistke-dannyh-v-python-2020-03-27
#
# На английском
#
# https://statisticsbyjim.com/basics/outliers/
#
# https://machinelearningmastery.com/how-to-use-statistics-to-identify-outliers-in-data/
#
# https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твои коррективы!

# %%
# Методом корреляционного анализа я определю зависимость изменения цены от факторов: total_area, cityCenters_nearest, rooms, floor, floors_total
print('Корреляционный анализ:')
print('площадь квартиры в квадратных метрах (м²)-цена', real_estate_data['total_area'].corr(real_estate_data['last_price']))
print('расстояние до центра города (м)-цена', real_estate_data['cityCenters_nearest'].corr(real_estate_data['last_price']))
print('число комнат- цена', real_estate_data['rooms'].corr(real_estate_data['last_price']))
print('этаж- цена',real_estate_data['floor'].corr(real_estate_data['last_price']))
print('всего этажей в доме- цена',real_estate_data['floors_total'].corr(real_estate_data['last_price']))
# Out:
# Корреляционный анализ:
# площадь квартиры в квадратных метрах (м²)-цена 0.6565293697111821
# расстояние до центра города (м)-цена -0.2219351215294363
# число комнат- цена 0.4203310164443171
# этаж- цена 0.17003357461075766
# всего этажей в доме- цена 0.2568912286248358

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b>
#
# Наталья, для Санкт-Петербурга (вернее,центра города) то, какие факторы влияют на цену, ты будешь смотреть на последующем шаге. Для начала надо применить корреляцию для анализа того, какие факторы влияют на цену жилья в Санкт-Петербурге (здесь имеется в виду Спб и пригороды, только Спб - следующий шаг анализа), сводная таблица не совсем продуктивный метод в данном случае, хотя в целом он показывает определенные закономерности. Постарайся доработать этот шаг, добавив корреляционный анализ и не выделяя отдельно Санкт-Петербург по факторам, которые ты вывела выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Да, в целом все верно!

# %% [markdown]
# ## Вывод

# %% [markdown]
# Проведя корреляционный анализ я пришла к выводу:
# - больше всего на рост цен влияет общая площать квартиры
# - меньше всего влияет этаж
# - расстояние от центра наоборот приводит к снижению цены, это я поняла получив отрицательное значение коэффициента Пирсона

# %%
#для анализа добавили параметры группировки данных по столбцам: первом, последнем или другом этажах
# и вывели median значение цены на квартиру
gr = real_estate_data.groupby(['floor_naim'])['last_price'].agg([min, max])
display(gr)
ax = gr.plot(kind='bar', title ="Сравнительный график: Этаж - Цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Этаж", fontsize=12)
ax.set_ylabel("Цена", fontsize=12)
plt.show()
# Out:
#                  min         max
# floor_naim
# Другой      450000.0  10800000.0
# Первый      430000.0  10800000.0
# Последний    12190.0  10800000.0

# %% [markdown]
# ## Вывод

# %% [markdown]
# Результат проверки показал, что этажи в категории Другой имеют более высокую цену, чем первый.
#
# Последний этаж немного больше первого

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b>
#
# не совсем корректные результаты: на самом деле этажность влияет, квартиры на первом этаже по логике дешевле. Попробуй перепроверить результаты своего анализа.
#
# Используй в том числе графический метод, в частности, столбчатую диаграмму.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Получился интересный график!

# %%
#для анализа добавили параметры группировки данных по столбцам: день недели
# и вывели min и max значение цены на квартиру
display(real_estate_data.pivot_table(index=['day_week'], values='last_price', aggfunc=[min, max]))

gr = real_estate_data.groupby(['day_week'])['last_price'].agg([min, max])
ax = gr.plot(kind='bar', title ="Сравнительный график: День недели - Цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("День недели", fontsize=12)
ax.set_ylabel("Цена", fontsize=12)
plt.show()
# Out:
#                    min         max
#             last_price  last_price
# day_week
# Воскресенье   470000.0  10800000.0
# Вторник       430000.0  10800000.0
# Понедельник   430000.0  10800000.0
# Пятница       450000.0  10800000.0
# Среда          12190.0  10800000.0
# Суббота       550000.0  10750000.0
# Четерг        450000.0  10800000.0

# %% [markdown]
# ## Вывод

# %% [markdown]
# Закономерность стоимости квартиры от дня недели опубликования обьявления не наблюдается

# %%
#для анализа добавили параметры группировки данных по столбцам: месяцы
# и вывели min и max значение цены на квартиру
display(real_estate_data.pivot_table(index=['month'], values='last_price', aggfunc=[min, max]))

gr = real_estate_data.groupby(['month'])['last_price'].agg([min, max])
ax = gr.plot(kind='bar', title ="Сравнительный график: Месяц - Цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Месяц", fontsize=12)
ax.set_ylabel("Цена", fontsize=12)
plt.show()
# Out:
#                 min         max
#          last_price  last_price
# month
# Август     450000.0  10800000.0
# Апрель     430000.0  10800000.0
# Декабрь    490000.0  10700000.0
# Июль       440000.0  10800000.0
# Июнь       430000.0  10700000.0
# Май        490000.0  10800000.0
# Март        12190.0  10626000.0
# Ноябрь     560000.0  10800000.0
# Октябрь    600000.0  10700000.0
# Сентябрь   520000.0  10800000.0
# Февраль    450000.0  10800000.0
# Январь     480000.0  10800000.0

# %% [markdown]
# ## Вывод

# %% [markdown]
# Статистика цен на квартиры показало что в январе, октябре самые высокие цены на квартиры. Самые низкие цены в июне и в сентябре.

# %%
#для анализа добавили параметры группировки данных по столбцам: год
# и вывели min и max значение цены на квартиру
display(real_estate_data.pivot_table(index=['year'], values='last_price', aggfunc=[min, max]))

gr = real_estate_data.groupby(['year'])['last_price'].agg([min, max])
ax = gr.plot(kind='bar', title ="Сравнительный график: Год - Цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Год", fontsize=12)
ax.set_ylabel("Цена", fontsize=12)
plt.show()
# Out:
#             min         max
#      last_price  last_price
# year
# 2014  1200000.0  10700000.0
# 2015   650000.0  10800000.0
# 2016   490000.0  10800000.0
# 2017   450000.0  10800000.0
# 2018   430000.0  10800000.0
# 2019    12190.0  10800000.0

# %% [markdown]
# ## Вывод

# %% [markdown]
# С 2014 года наблюдался рост цен на квартиры, максимальная стоимость было 2016-2017 годах. После пошёл небольшой спад цен.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍</b>
#
# Результаты по анализу времени публикации объявлений и ихвлиянии на цену верны, молодец, хорошая работа!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Стоит дополнить таблицы графиками!

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что ты добавила визуализацию и корректно ее оформила, хорошая работа!

# %%
# получаем 10 населенных пунктов с максимальным числом обьявлением
counts = real_estate_data['locality_name'].value_counts().head(10).index.tolist()

#Считаем среднюю цену квадратного метра в этих населённых пунктах
for i in counts:
    p = real_estate_data.query('locality_name == @i')['last_price'].sum()
    s = real_estate_data.query('locality_name == @i')['total_area'].sum()
    r = p/s
    print(i, round(r, 2))
# Out:
# Санкт-Петербург 103023.88
# посёлок Мурино 83207.93
# посёлок Шушары 76196.36
# Всеволожск 66407.14
# посёлок Парголово 87110.87
# Колпино 73620.53
# Пушкин 99587.07
# Гатчина 67680.26
# деревня Кудрово 90743.15
# Петергоф 82514.18

# %% [markdown]
# ## Вывод

# %% [markdown]
# Собрала список городов с максимальным количеством обьявлений и расчитали для них среднюю стоимость кв.м.
# В результате населеный пункт Петергоф самая минимальная стоимость жилья 82514.18 рублей за кв.м, а в Санкт-Петербурге самая дорогая стоимость жилья- 103023.88 рублей за кв.м

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍</b>
#
# Топ-10 населенный пунктов определены верно!

# %%
# Выбераем данные по городу Санкт-Петербург
real_estate_data_piter = real_estate_data.query('locality_name =="Санкт-Петербург"')

# цикл для записи данных в новый столбцы cityCenters и price_cityCenters
# cityCenters- расстояние округляем до целого числа, переводим в километры
# price_cityCenters - стоимость за каждый километр до центра города
for i,r in real_estate_data_piter.iterrows():
    сс = math.ceil(real_estate_data_piter.loc[i,'cityCenters_nearest']/1000)
    real_estate_data_piter.loc[i,'cityCenters'] = сс
    real_estate_data_piter.loc[i,'price_cityCenters'] = real_estate_data_piter.loc[i,'last_price']/сс

#расчет средней цены за километр до центра
avg_price_cityCenters = real_estate_data_piter['price_cityCenters'].mean()

print('Cредняя цена для каждый километр:', avg_price_cityCenters )

# Строим график для наглядного сравнения расстояния от центра и средней ценой за квадратный метр
gr = real_estate_data_piter.groupby(['cityCenters'])['price_cityCenters'].agg([min, max])
ax = gr.plot(kind='bar', title ="Сравнительный график: Расстояние от центра города - Средняя цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Расстояние от центра города", fontsize=12)
ax.set_ylabel("Средняя цена", fontsize=12)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Cредняя цена для каждый километр: 518011.3185866575

# %% [markdown]
# ## Вывод

# %% [markdown]
# Изучаем предложения квартир в Санкт_Петрбурге, в столбцы:
#
# - cityCenters сделали округление до целого числа и перевели метры в километры
# - price_cityCenters стоимость за каждый километр до центра города
#
# Расчитали  среднюю цены за километр до центра города, она составила 518011.31 рублей
#
# Построили график показателями которого стали price_cityCenters и cityCenters.
# На графике видно изменения цены в зависимости отдаленности от центра города. На графике мы можем определить центральную зону, котоая начинается с 1 км до 8 км.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Более адекватная цифра для зоны центра это около 7-8 км, 10 уже многовато! Попробуй для наглядности использовать другие типы графика: линейный или диаграмму рассеяния.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Теперь зона центра определена корректно! График тоже выглядит отлично!

# %%
#Выводим обьявления у которых расстояние до центра от 1 до 8км
t = real_estate_data_piter.query('1 <= cityCenters <= 8')

# Анализ по столбцам площадь, цена, число комнат, высота потолков, этаж, расстояние до центра
print('Корреляционный анализ:')
print('площадь квартиры в квадратных метрах (м²)- цена', t['total_area'].corr(t['last_price']))
print('высота потолков (м)- цена', t['ceiling_height'].corr(t['last_price']))
print('число комнат- цена', t['rooms'].corr(t['last_price']))
print('этаж- цена', t['floor'].corr(t['last_price']))
print('расстояние до центра города (м)- цена', t['cityCenters'].corr(t['last_price']))

gr = t.groupby(['rooms'])['last_price'].agg([min, max])
display(gr)
ax = gr.plot(kind='bar', title ="Сравнительный график квартир в центре: Кол-во комнат - Цена", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Кол-во комнат", fontsize=12)
ax.set_ylabel("Цена", fontsize=12)
plt.show()
# Out:
# Корреляционный анализ:
# площадь квартиры в квадратных метрах (м²)- цена 0.6461190430905877
# высота потолков (м)- цена 0.07156384668333625
# число комнат- цена 0.4464193123849034
# этаж- цена 0.12245888943944754
# расстояние до центра города (м)- цена -0.1553524014280156
#              min         max
# rooms
# 0      2100000.0   7400000.0
# 1      1900000.0  10650000.0
# 2      3000000.0  10800000.0
# 3      1600000.0  10800000.0
# 4      2100000.0  10800000.0
# 5      1800000.0  10800000.0
# 6      9100000.0   9100000.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>На доработку🤔:</b>
#
# Наталья, анализ рынка жилья в центре стоит провести по аналогии с анализом рынка жилья в целом в Санкт-Петербурге: нужно построить те же графики, корреляции, и самое главное, в выводе сравнить результаты, которые ты получил по центру города с результатами, которые ты получил по всему городу на первых этапах анализа. Это важнО, поскольку это одна из основных задач исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b>
#
# Все получилось, молодец!

# %% [markdown]
# ## Вывод

# %% [markdown]
# Изучаем предложения квартир в Санкт-Петрбурге в центральной зоне.
#
# Анализ по столбцам площадь, цена, число комнат, высота потолков, этаж, расстояние до центра.
# Я провела корреляционный анализ который показал:
# - самое высокое влияние на стоимость квартиры имеет ее площадь
# - на втором месте идет количество комнат
# - меньше всего влияет высота потолков
# - расстояние от центра города наоборот ведет к снижению цены
#
# В итоге можно решить что чем ближе к центру города, тем стоймость выше. И больше предпочтение в покупке квартиры отдают площади квартиры.

# %% [markdown]
# ### Шаг 5. Общий вывод
# <a id='Шаг 5. Общий вывод'></a>

# %% [markdown]
# ## Исследование объявлений о продаже квартир
#
#
# Архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет от Яндекс.Недвижимость.
#
# <h4>Цель проекта:</h4> Научиться определять рыночную стоимость объектов недвижимости с разными параметрами в обьявлениях
#
# Краткий отчет проделанной работе:
#
# В полученной файле были данные с 23 699 записью.
#
# Описание данных:
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах(м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении
#
# Даныне прошли предобработку:
#
# <h6>Предобработка данных:</h6> Заполнены пропущенные записи там где они треборвались для дальнейшего использования, изменены типы данных, для расчетов, для работы с датой
#
#  В следующих столбцах:
#
# - ceiling_height
# - balcony
# - floors_total
# - living_area
# - total_area
# - kitchen_area
# - cityCenters_nearest
# - last_price
# - first_day_exposition
# - days_exposition
#
#
#
# <h6>Посчитала и добавила в таблицу:</h6>
#
# - price_kv -Цена квадратного метра с округлением
# - day_week- День недели
# - month- Месяц
# - year- Год
# - floor_naim - этажность
# - K -  соотнощения  жилой и общей площади
# - K_kitchen - отношение площади кухни к общей
#
# <h6>Провела исследовательский анализ данных</h6>
#
# - Гистограмма площади квартиры в квадратных метрах:
#  Стало известно что гистограмма начинает свой показатель от 12 м.кв площади квартир. Пиком графика, а значит большим спросом покупки квартиры площадью от 60 м.кв. Меньшим спросом квартиры от 100 м.кв. Распределение спроса квартир в нормальной форме графика,у которого симметричная форма колокола с пиком посередине
#
# - Гистограмма цен на квартиры:
#  Размерность цен на квартиру начинается от 12 тысяч рубллей, пиком ценового показателя в области 6 миллионов рублей. Большой пикой на графике показан почти 75% сумма квартир от 6.8 млн. рублей
#
# - Гистограмма число комнат в квартирах:
#  График показал рынок квартир с кол-вами комнат. Из 23 699 предложенных вариантов, предпочтение составляет 50% 2-х комнатные квартиры, 75 % 3-х комнатные апартаменты. График показывает большие обрывы между предложенными вариантами количеств в обьявлениях.
#
# - Гистограмма высота потолков в квартирах:
#  График  показал варианты квартир с высотой потолков. В обьявлениях средний размер высота потолков составляет 2,5 м. 75% обьявлений преддогают потолки с высотой 2,7м. Максимальная высота потолков 3 м. Еще надо помнить что в части где была обработка данных я провела выброс данных с помощью метода Боксплота
#
# - Гистограмма по времени продажи квартиры:
#  График показывает кол-во дней публикации обьявления продажи квартиры. В среднем обьявление имеет статус публикации 95 дней, среднее арифметическое кол-во дней публикации обьявления равна 176 дней. Можно считать, что продажи прошли очень быстро, если количество дней публикации объвления значительно меньше медианы и соответственно долго когда количество дней публикации больше среднее арифметического.
#
# Методом boxplot получили нормальные значения цен на квартиры. Границы квантилий от 12190 до 10800000 руб.
#
# Методом корреляционного анализа я определю зависимость изменения цены от факторов:
#
# - площадь квартиры в квадратных метрах (м²)-цена 0.6565293697111821
# - расстояние до центра города (м)-цена -0.2219351215294363
# - число комнат- цена 0.4203310164443171
# - этаж- цена 0.17003357461075766
# - всего этажей в доме- цена 0.2568912286248358
#
# Выводы:
# - Больше всего на рост цен влияет общая площать квартиры, меньше всего влияет этаж. Расстояние от центра наоборот приводит к снижению цены, это я поняла получив отрицательное значение коэффициента Пирсона
# - Результат проверки показал, что этажи в категории Другой имеют более высокую цену, чем первый. Последний этаж немного больше первого
# - Закономерность стоимости квартиры от дня недели опубликования обьявления не наблюдается
# - Статистика цен на квартиры показало что в январе, октябре самые высокие цены на квартиры. Самые низкие цены в июне и в сентябре.
# - С 2014 года наблюдался рост цен на квартиры, максимальная стоимость было 2016-2017 годах. После пошёл небольшой спад цен.
#
# Выделила 10 крупных населнных пунктов с максимальным числом обьявлением и посчитали среднюю цену квадратного метра в этих населённых пунктах:
#
# - Санкт-Петербург 103023.88
# - посёлок Мурино 83207.93
# - посёлок Шушары 76196.36
# - Всеволожск 66407.14
# - посёлок Парголово 87110.87
# - Колпино 73620.53
# - Пушкин 99587.07
# - Гатчина 67680.26
# - деревня Кудрово 90743.15
# - Петергоф 82514.18
#
# Собрала список городов с максимальным количеством обьявлений и расчитали для них среднюю стоимость кв.м.
# В результате населеный пункт Петергоф самая минимальная стоимость жилья 82514.18 рублей за кв.м, а в Санкт-Петербурге самая дорогая стоимость жилья- 103023.88 рублей за кв.м
#
#
# <h6>Изучаем предложения квартир в Санкт_Петрбурге</h6>
#
# В столбцы:
#
# - cityCenters сделала округление до целого числа и перевели метры в километры
#
# - price_cityCenters стоимость за каждый километр до центра города
#
# - Расчитали среднюю цены за километр до центра города, она составила 518011.31 рублей
#
# Построила график  показателями которого стали price_cityCenters и cityCenters. На графике видно изменения цены в зависимости отдаленности от центра города. На графике мы можем определить центральную зону, котоая начинается с 1 км до 8 км. Это называется центральная зона.
#
# Методом корреляционного анализа я определю зависимость изменения цены от факторов:
# - площадь квартиры в квадратных метрах (м²)- цена 0.6461190430905877
# - высота потолков (м)- цена 0.07156384668333625
# - число комнат- цена 0.4464193123849034
# - этаж- цена 0.12245888943944754
# - расстояние до центра города (м)- цена -0.1553524014280156
#
#
# Изучила предложения квартир в Санкт-Петрбурге в центральной зоне.  Корреляционный анализ по столбцам площадь, цена, число комнат, высота потолков, этаж, расстояние до центра.
# - самое высокое влияние на стоимость квартиры имеет ее площадь
# - на втором месте идет количество комнат
# - меньше всего влияет высота потолков
# - расстояние от центра города наоборот ведет к снижению цены
#
# <h6>Итог.</h6>
# Чем ближе к центру города, тем стоймость квартиры выше. И больше предпочтение в покупке квартиры отдают площади квартиры.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Наталья, спасибо за твой проект! Ты приложила много усилий, чтобы довести его до конца, многие задачи в рамках проекта у тебя получились, проделана огромная работа, и это видно невооруженным глазом, ты большая молодец! Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * На разных шагах проекта ты предлагала очень интересные решения и методы для их реализации. Хорошая работа!
# * Здорово, что ты использовала автоматизацию для выполнения задач, писала свои функции.
# * Ты использовала самые разные методы для работы с данными, все получилось!
# * Ты использовала визуализацию, хорошо, что ты не избегаешь этого инструмента анализа!
#
# **На что стоит обратить внимание🤓**:
# * Важно обратить внимание на оформление графиков! Визуализация - это зачастую визитная карточка проекта, важно уделять внимание ее оформлению!
# * Стоит обратить внимание на работу с пропусками: думать над заполнением пропусков в случае колонок, в которых их доля превышает 10%, и использовать более сложные стратегии, в целом, соблюдать баланс и адекватность подхода к заполнению пропусков.
# * В некоторых случаях у тебя получились не совсем корректные результаты, стоит перепроверить работу еще раз.
# * Важно добавить корреляционный анализ и провести анализ центра Спб и Спб(+ пригороды, не стоит выделять Спб отдельно) аналогично.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту: вторая итерация ревью**
#
# Наталья, спасибо, что прислала проект с доработками! Тебе удалось значительно улучшить проект, ты улучшила визуализацию, доработала ряд шагов анализа, спасибо за терпение и желание довести проект до конца, у тебя все отлично получается, дальше - больше и лучше!
# Спешу тебе сообщить, что твой проект принят, и ты можешь перейти на следующий спринт!
#
# **Желаю тебе крутых и интересных проектов на следующих спринтах**😉
# ![gif](https://media.giphy.com/media/HXF45CT8cvzZC/giphy.gif)

# %% [markdown]
# ### Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
