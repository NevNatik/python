# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Привет, Наталья!</b>
#
# Меня зовут Ярослав П. и мы с тобой уже знакомы. Рад поработать вместе снова!
#
# Предлагаю общаться на «**ты**». Если это неприемлемо, обязательно напиши мне в комментариях — мы перейдем на «**вы**».
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b> Так выделены небольшие замечания или советы.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
# ### <span style="color:orange">Обратная связь</span><a class="tocSkip">
#
# - Проект отлично выполнен.
# - В проекте наглядная (но ее можно немного улучшить, оставил комментарий) визуализация и верные выводы по графикам.
# - Пожалуйста, не забывай про общий вывод 😉
#
# Проект принят, успехов в дальнейшем обучении!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Аналитика" data-toc-modified-id="Аналитика-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Аналитика</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Спрос на рейсы авиакомпании

# %% [markdown]
# Вы аналитик российской авиакомпании F9, выполняющей внутренние пассажирские перевозки. Важно понять предпочтения пользователей, покупающих билеты на разные направления.
#
# Вам предстоит изучить базу данных и проанализировать спрос пассажиров на рейсы в города, где проходят крупнейшие культурные фестивали.

# %% [markdown]
# У вас есть файлы с результатами запросов из предыдущих заданий.
#
# **query_1.csv** — результат первого запроса. В нём содержится такая информация:
#
# - *model* — **модель самолета;
# - *flights_amount* — количество рейсов для каждой модели самолетов *model* в сентябре 2018 года.
#
# **query_3.csv** — результат третьего запроса. В нём содержится такая информация:
#
# - *city* — город;
# - *average_flights* — среднее количество рейсов, прибывающих в город (*city*) за день в сентябре 2018 года.
#
#  Для этих двух наборов данных нужно:
#
# - импортировать файлы;
# - изучить данные в них;
# - проверить типы данных на корректность;
# - выбрать топ-10 городов по количеству рейсов;
# - построить графики: модели самолётов и количество рейсов, города и количество рейсов, топ-10 городов и количество рейсов;
# - сделать выводы по каждому из графиков, пояснить результат.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Отличное введение.
#
# </div>

# %% [markdown]
# ## Аналитика

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# 1. импортировать файлы;

# %%
query_1 = pd.read_csv('/datasets/query_1.csv')
query_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# model             8 non-null object
# flights_amount    8 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
query_3 = pd.read_csv('/datasets/query_3.csv')
query_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
# city               101 non-null object
# average_flights    101 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# 2. изучить данные в них;
# 3. проверить типы данных на корректность;

# %%
query_1
# Out:
#                  model  flights_amount
# 0      Airbus A319-100             607
# 1      Airbus A321-200             960
# 2       Boeing 737-300             630
# 3       Boeing 767-300             600
# 4       Boeing 777-300             300
# 5   Bombardier CRJ-200            4446
# 6   Cessna 208 Caravan            4557
# 7  Sukhoi SuperJet-100            4185

# %%
query_3
# Out:
#                city  average_flights
# 0            Абакан         3.870968
# 1           Анадырь         1.000000
# 2             Анапа         2.161290
# 3       Архангельск         5.354839
# 4         Астрахань         2.451613
# ..              ...              ...
# 96             Чита         1.580645
# 97           Элиста         4.870968
# 98   Южно-Сахалинск         4.290323
# 99           Якутск         2.741935
# 100       Ярославль         1.322581
#
# [101 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Отличный первый взгляд на данные.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Также можно проверить вторую таблицу на наличие дубликатов. И было бы здорово оставить комментарий по итогам первого шага - все ли в порядке.
#
# </div>

# %% [markdown]
# Изменим тип данных для average_flights на целочисленный тип

# %%
query_3['average_flights'] = query_3['average_flights'].astype('int')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# В данном случае это лишнее действие, так как теряется большАя часть информации, по которой мы можем корректно сортировать этот датафрейм.
#
# </div>

# %% [markdown]
# 4. выбрать топ-10 городов по количеству рейсов;

# %%
top10=query_3.sort_values(by='average_flights', ascending=False).head(10)
top10
# Out:
#                city  average_flights
# 43           Москва              129
# 70  Санкт-Петербург               31
# 54      Новосибирск               17
# 20     Екатеринбург               11
# 33       Красноярск               11
# 63            Пермь               10
# 67   Ростов-на-Дону               10
# 10           Брянск               10
# 84        Ульяновск                9
# 73        Советский                9

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Все верно. Также этот список можно получить с помощью pandas метода [nlargest](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nlargest.html).
#
# </div>

# %% [markdown]
# 5. построить графики: модели самолётов и количество рейсов, города и количество рейсов, топ-10 городов и количество рейсов;

# %%
graf= query_1.sort_values(by='flights_amount')

sns.set_style("white")
plt.figure(figsize=(10, 7))
plt.title('График соотношения модели самолётов и количество рейсов', fontsize=20)
sns.barplot(x='model', y='flights_amount', data=graf, label="line")
sns.despine(left=True)
plt.xlabel('')
plt.ylabel('среднее количество рейсов', fontsize=14)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Здорово, что отсортировала данные перед построением графика - так наглядней.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Прошу не забывать подписывать ось х. Также, возможно, если повернуть график горизонтально, его наглядность бы еще повысилась.
#
# </div>

# %% [markdown]
# <b>Вывод: </b>
#
# Самолеты моделей Cessna 208 Caravan, Bombardier CRJ-200 и Sukhoi SuperJet-100 совершают значительно большее количество полетов, на графике видно большой отрыв по кол-ву рейсов. Меньше всего перелетов у крупнейшего Boeing 777-300

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Немного неожиданный результат, как думаешь, почему такие большие самолеты как Boeing'и и Airbus'ы даже в сумме летают меньше, чем небольшие самолеты?
#
# </div>

# %%
graf1= query_3.sort_values(by='average_flights', ascending=False)

sns.set_style("white")
plt.figure(figsize=(15, 30))
plt.title('График соотношения города и количество рейсов', fontsize=20)
sns.barplot(x='average_flights', y='city', data=graf1, palette='cool')
sns.despine(left=True)
plt.xlabel('среднее количество рейсов', fontsize=14)
plt.ylabel('')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# <b>Вывод: </b>
#
# По городам лидирует конечно же столица :). В Ярославль предпочитают добираться автотранспортом.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Москва есть Москва :)
#
# </div>

# %%
sns.set_style("white")
plt.figure(figsize=(15, 7))
plt.title('Топ-10 городов и количество рейсов', fontsize=20)
sns.barplot(x='city', y='average_flights', data=top10.sort_values(by='average_flights', ascending=True))
sns.despine(left=True)
plt.xlabel('')
plt.ylabel('количество рейсов', fontsize=14)
plt.show()

# %% [markdown]
# <b>Вывод: </b>
#
# Москва, Санкт-Петербург, Новосибирск. В остальных городах и

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Да, все верно, Москва, Санкт-Петербург и Новосибирск - крупные российские хабы.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Тут как будто потерялась часть вывода :) Прошу не забывать про общий вывод - это важная часть работы. Также было бы здорово расширить выводы и порассуждать о причинно-следственной связи полученных результатов.
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Файлы изучены
# - [ ]  Типы данных проверены на корректность
# - [ ]  Выбран топ-10 городов по количеству рейсов
# - [ ]  Построен график «Модели самолётов и количество рейсов»
# - [ ]  Построен график «Города и количество рейсов»
# - [ ]  Построен график «Топ-10 городов и количество рейсов»
# - [ ]  На каждом этапе написаны выводы
# - [ ]  Написан общий вывод
